# %%
import pandas as pd
import states_abbrevs
from states_abbrevs import dict2

# %%
jo = pd.read_csv('jo_statedata.csv',skiprows=4)

# %%
jo.shape
# Out:
# (11883, 13)

# %%
jo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11883 entries, 0 to 11882
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Period (YYYYMM)            11883 non-null  int64
#  1   State                      11883 non-null  object
#  2   Region                     11883 non-null  object
#  3   Job Openings               11883 non-null  int64
#  4   Hires                      11883 non-null  int64
#  5   Quits                      11883 non-null  int64
#  6   Layoffs & Discharges       11883 non-null  int64
#  7   Total Separations          11883 non-null  int64
#  8   Job Openings Rate          11883 non-null  float64
#  9   Hires Rate                 11883 non-null  float64
#  10  Quits Rate                 11883 non-null  float64
#  11  Layoffs & Discharges Rate  11883 non-null  float64
#  12  Total Separations Rate     11883 non-null  float64
# ...

# %%
jo
# Out:
#       State Region  Job Openings  Hires  Quits  Layoffs & Discharges  \
# 0        AL      S            67     65     39                    28
# 1        AK      W            14     17      8                     8
# 2        AZ      W           112    116     52                    53
# 3        AR      S            43     41     26                    19
# 4        CA      W           664    589    295                   253
# ...     ...    ...           ...    ...    ...                   ...
# 11878    VA      S           181    170     56                    89
# 11879    WA      W           120    162     40                    87
# 11880    WV      S            37     35     12                    23
# 11881    WI     MW           114    136     37                    65
# 11882    WY      W            16     25      5                    16
#
#        Total Separations  Job Openings Rate  Hires Rate  Quits Rate  \
# 0                     73                3.3         3.3         2.0
# ...

# %% [markdown]
# ### Columns

# %%
jo.rename(columns={'Period (YYYYMM)':'Period'}, inplace=True)
jo['State'] = jo['State'].map(dict2)

# %% [markdown]
# ## Seperating year and month

# %%
#first change to datetime
jo['Period'] = pd.to_datetime(jo['Period'], format = '%Y%m')
jo['Year'] = jo['Period'].dt.year
jo['Month'] = jo['Period'].dt.month
jo.drop('Period',axis=1,inplace=True)

# %% [markdown]
# dropping years earlier than 2012

# %%
jo = jo[jo.Year > 2011]
# Out:
#       State Region  Job Openings  Hires  Quits  Layoffs & Discharges  \
# 6681     AL      S            60     61     33                    33
# 6682     AK      W            10     11      6                     7
# 6683     AZ      W            79     69     34                    32
# 6684     AR      S            28     34     17                    17
# 6685     CA      W           359    382    171                   211
# ...     ...    ...           ...    ...    ...                   ...
# 11878    VA      S           181    170     56                    89
# 11879    WA      W           120    162     40                    87
# 11880    WV      S            37     35     12                    23
# 11881    WI     MW           114    136     37                    65
# 11882    WY      W            16     25      5                    16
#
#        Total Separations  Job Openings Rate  Hires Rate  Quits Rate  \
# 6681                  71                3.0         3.2         1.7
# ...
